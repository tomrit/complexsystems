# %%
import sympy
sympy.Symbol
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-0de5941561d2> in <module>()
#       1 import sympy
# ----> 2 sympy.Symb
#
# AttributeError: module 'sympy' has no attribute 'Symb'

# %%
x1 = sympy.Symbol('x_1')
x2 = sympy.Symbol('x_2')
x3 = sympy.Symbol('x_3')

# %%
x1_step = 3.8 * x1 * (1 - x1) - 0.05 * (0.35 + x2) * (1 - 2 * x3)
x2_step = 0.1 * ((x2 + 0.35) * (1 - 2 * x3) - 1) * (1 - 1.9 * x1)
x3_step = 3.78 * x3 * (1 - x3) + 0.2 * x2

# %%
type(x1_step)
# Out:
# sympy.core.add.Add

# %%
import folded_towel_map

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import imp

# %%
imp.reload(folded_towel_map)
N = 10000
x0 = [1,1,1]
xn = folded_towel_map.iterate_map(N,x0)

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot(xn[:,0], xn[:,1], xn[:,2], '.')
plt.show()
